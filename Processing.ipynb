# %% [markdown]
# # **PROCESSING**

# %%
#Import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Dataset
from google.colab import files

uploaded = files.upload()  # This will prompt you to upload a file
# Out:
#      <input type="file" id="files-6c888f11-21c4-4146-af48-746908d8a574" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c888f11-21c4-4146-af48-746908d8a574">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Display shape as a table
df_Processing = pd.read_csv('processing.csv')

# Show the first 5 rows of the dataset
df_Processing.head()
# Out:
#    process_id diamond_id assigned_cutter cutting_style polishing_stage  \
# 0  PROC000001  DIA017339        Cutter_1          Oval           Final
# 1  PROC000002  DIA014663        Cutter_2      Princess         Initial
# 2  PROC000003  DIA016774        Cutter_3       Emerald         Initial
# 3  PROC000004  DIA015769        Cutter_4          Oval    Intermediate
# 4  PROC000005  DIA002426        Cutter_5         Round         Initial
#
#    estimated_yield_carat  actual_yield_carat  waste_percentage     status  \
# 0                   6.79                8.06             23.22     Failed
# 1                   7.32                2.65             43.56     Failed
# 2                   0.28                5.47             27.97  Completed
# 3                   5.43                8.16              3.00     Failed
# 4                   4.88                6.55             13.80     Failed
#
#   completion_date
# 0      2023-03-08
# 1      2024-09-23
# 2      2020-01-09
# ...

# %% [markdown]
# # **DATA OVERVIEW**

# %%
# Shape of table
df_Processing.shape
# Out:
# (20000, 10)

# %%
# Info about table
df_Processing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   process_id             20000 non-null  object
#  1   diamond_id             20000 non-null  object
#  2   assigned_cutter        20000 non-null  object
#  3   cutting_style          20000 non-null  object
#  4   polishing_stage        20000 non-null  object
#  5   estimated_yield_carat  20000 non-null  float64
#  6   actual_yield_carat     20000 non-null  float64
#  7   waste_percentage       20000 non-null  float64
#  8   status                 20000 non-null  object
#  9   completion_date        20000 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.5+ MB

# %%
# Interpretation of the Dataset
# We have 20,000 observations and 10 columns.
# We have 3 numerical columns and 7 categorical columns.
# There are no missing values in the dataset.

# %%
# Describe the data
df_Processing.describe()
# Out:
#        estimated_yield_carat  actual_yield_carat  waste_percentage
# count           20000.000000        20000.000000      20000.000000
# mean                4.574042            4.537517         25.430556
# std                 2.565598            2.572851         14.158510
# min                 0.100000            0.100000          1.000000
# 25%                 2.350000            2.290000         13.207500
# 50%                 4.580000            4.530000         25.475000
# 75%                 6.790000            6.790000         37.690000
# max                 9.000000            9.000000         50.000000

# %%
# Interpretation
# We have 3 Numerical Columns

# %%
# Show columns
df_Processing.columns
# Out:
# Index(['process_id', 'diamond_id', 'assigned_cutter', 'cutting_style',
#        'polishing_stage', 'estimated_yield_carat', 'actual_yield_carat',
#        'waste_percentage', 'status', 'completion_date'],
#       dtype='object')

# %%
# Intrepretation
# Process_ID → Unique identifier for the processing stage.
# Diamond_ID → Unique diamond identification.
# Assigned_Cutter → The person assigned for cutting the diamond.
# Cutting_Style → The style in which the diamond is cut.
# Polishing_Stage → Current stage of the diamond in the polishing process.
# Status → Processing status of the diamond.
# Completion_Date → Date when the process was completed.
# Estimated_Yield_Carat → Estimated weight of the final diamond in carats.
# Actual_Yield_Carat → Actual weight of the final diamond in carats.
# Waste_Percentage → Percentage of material wasted during processing.

# %% [markdown]
# DATA PREPROCESSING

# %% [markdown]
# # **DATA CLEANING**

# %%
df_Processing.rename(columns={
    'process_id': 'Process_ID',
    'diamond_id': 'Diamond_ID',
    'assigned_cutter': 'Assigned_Cutter',
    'cutting_style': 'Cutting_Style',
    'polishing_stage': 'Polishing_Stage',
    'estimated_yield_carat': 'Estimated_Yield_Carat',
    'actual_yield_carat': 'Actual_Yield_Carat',
    'waste_percentage': 'Waste_Percentage',
    'status': 'Status',
    'completion_date': 'Completion_Date'}, inplace=True)

# %%
# Show columns
df_Processing.columns
# Out:
# Index(['Process_ID', 'Diamond_ID', 'Assigned_Cutter', 'Cutting_Style',
#        'Polishing_Stage', 'Estimated_Yield_Carat', 'Actual_Yield_Carat',
#        'Waste_Percentage', 'Status', 'Completion_Date'],
#       dtype='object')

# %% [markdown]
# # **NULL VALUE HANDLING**

# %%
# Check null count
df_Processing.isnull().sum()
# Out:
# Process_ID               0
# Diamond_ID               0
# Assigned_Cutter          0
# Cutting_Style            0
# Polishing_Stage          0
# Estimated_Yield_Carat    0
# Actual_Yield_Carat       0
# Waste_Percentage         0
# Status                   0
# Completion_Date          0
# dtype: int64

# %%
# Interpretation
# We dont have the null records

# %% [markdown]
# # **EDA**

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %%
# show columns
df_Processing.columns
# Out:
# Index(['Process_ID', 'Diamond_ID', 'Assigned_Cutter', 'Cutting_Style',
#        'Polishing_Stage', 'Estimated_Yield_Carat', 'Actual_Yield_Carat',
#        'Waste_Percentage', 'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Process ID

# %%
# Count
df_Processing['Process_ID'].value_counts().head()
# Out:
# Process_ID
# PROC000001    1
# PROC013331    1
# PROC013338    1
# PROC013337    1
# PROC013336    1
# Name: count, dtype: int64

# %%
# Drop
df_Processing.drop('Process_ID', axis=1, inplace=True)

# %%
# Intrepretation
# We have droped Processing column because it has unique values.

# %%
# Show columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Assigned_Cutter', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Diamond ID

# %%
# Count
df_Processing['Diamond_ID'].value_counts().head()
# Out:
# Diamond_ID
# DIA014989    7
# DIA014368    6
# DIA010672    6
# DIA013251    6
# DIA005534    6
# Name: count, dtype: int64

# %%
# Plot the bar chart
df_Processing.Diamond_ID.value_counts().head().plot(kind='bar')
plt.show()

# %%
# Intrepretation
# We have IMP data for Diamonds
# DIA014989 → 7
# DIA014368 → 6
# DIA010672 → 6
# DIA013251 → 6
# DIA005534 → 6

# %%
# columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Assigned_Cutter', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Assigned_Cutter

# %%
# Count
df_Processing['Assigned_Cutter'].value_counts().head()
# Out:
# Assigned_Cutter
# Cutter_1        1
# Cutter_13331    1
# Cutter_13338    1
# Cutter_13337    1
# Cutter_13336    1
# Name: count, dtype: int64

# %%
# Drop
df_Processing.drop('Assigned_Cutter', axis=1, inplace=True)

# %%
# Intrepretation
# We have droped Processing column because it has unique values.

# %%
# Show columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Cutting Style

# %%
# Count
df_Processing['Cutting_Style'].value_counts().head()
# Out:
# Cutting_Style
# Cushion     4107
# Round       4005
# Oval        3967
# Emerald     3963
# Princess    3958
# Name: count, dtype: int64

# %%
# Plot
df_Processing.Cutting_Style.value_counts().head().plot(kind='bar')
plt.show()

# %%
#Intrepretation
# Imp info about Cutting Style
# Cushion   → 4107
# Round     → 4005
# Oval      → 3967
# Emerald   → 3963
# Princess  → 3958

# %%
# columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Polishing Stage

# %%
# Count
df_Processing['Polishing_Stage'].value_counts().head()
# Out:
# Polishing_Stage
# Final           6713
# Initial         6647
# Intermediate    6640
# Name: count, dtype: int64

# %%
# Plot
df_Processing.Polishing_Stage.value_counts().head().plot(kind='bar')
plt.show()

# %%
# Intrepretation
# We have got the IMP Info for Polishing Stage
# Final         → 6713
# Initial       → 6647
# Intermediate  → 6640

# %%
# Show Columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Estimated_Yield_Carat

# %%
# Count
df_Processing['Estimated_Yield_Carat'].value_counts().head()
# Out:
# Estimated_Yield_Carat
# 1.31    36
# 1.50    36
# 8.72    36
# 4.32    35
# 3.82    35
# Name: count, dtype: int64

# %%
# Plot
df_Processing.Estimated_Yield_Carat.value_counts().head().plot(kind='bar')
plt.show()

# %%
# # Intrepretation
# We have got the IMP Info for Estimated_Yield_Carat
# 1.31  → 36
# 1.50  → 36
# 8.72  → 36
# 4.32  → 35
# 3.82  → 35

# %%
# Show columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Actual_Yield_Carat

# %%
# Count
df_Processing['Actual_Yield_Carat'].value_counts().head()
# Out:
# Actual_Yield_Carat
# 4.59    39
# 2.10    37
# 3.12    37
# 7.61    36
# 1.69    36
# Name: count, dtype: int64

# %%
# Plot
df_Processing.Actual_Yield_Carat.value_counts().head().plot(kind='bar')
plt.show()

# %%
# Intrepretation
# We have got the IMP Info for Actual_Yield_Carat
# 4.59  → 39
# 2.10  → 37
# 3.12  → 37
# 7.61  → 36
# 1.69  → 36

# %%
# Columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Waste_Percentage

# %%
# Count
df_Processing['Waste_Percentage'].value_counts().head()
# Out:
# Waste_Percentage
# 5.50     13
# 36.45    11
# 22.67    11
# 21.09    11
# 42.66    11
# Name: count, dtype: int64

# %%
# Plot
df_Processing.Waste_Percentage.value_counts().head().plot(kind='bar')
plt.show()

# %%
# Intrepretation
# We have got the IMP Info for Waste Precentage
# 5.50   → 13
# 36.45  → 11
# 22.67  → 11
# 21.09  → 11
# 42.66  → 11

# %%
# Show the columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Status

# %%
# Count
df_Processing['Status'].value_counts().head()
# Out:
# Status
# In Progress    6766
# Failed         6690
# Completed      6544
# Name: count, dtype: int64

# %%
# PLot
df_Processing.Status.value_counts().head().plot(kind='bar')
plt.show()

# %%
# Intrepretation
# We have got the IMP Info for Status
# In Progress  → 6766
# Failed       → 6690
# Completed    → 6544

# %%
# columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# Completion_Date

# %%
# Count
df_Processing['Completion_Date'].value_counts().head()
# Out:
# Completion_Date
# 2020-12-09    27
# 2020-05-02    25
# 2024-08-01    23
# 2023-07-06    22
# 2024-11-26    22
# Name: count, dtype: int64

# %%
# Plot
df_Processing.Completion_Date.value_counts().head().plot(kind='bar')
plt.show()

# %%
# Intrepretation
# We have got the IMP Info Completion_Date
# 2020-12-09  → 27
# 2020-05-02  → 25
# 2024-08-01  → 23
# 2023-07-06  → 22
# 2024-11-26  → 22

# %%
# columns
df_Processing.columns
# Out:
# Index(['Diamond_ID', 'Cutting_Style', 'Polishing_Stage',
#        'Estimated_Yield_Carat', 'Actual_Yield_Carat', 'Waste_Percentage',
#        'Status', 'Completion_Date'],
#       dtype='object')

# %%
# We have done the Univariate Analysis of all the Categorical columns.

# %% [markdown]
# # **BIVARIATE ANALYSIS**

# %%
# lets segrigate the data based on the datatype
df_num = df_Processing.select_dtypes(include=['int64','float64'])
df_cat = df_Processing.select_dtypes(include=['object'])
df_num.head()
df_cat.head()
# Out:
#   Diamond_ID Cutting_Style Polishing_Stage     Status Completion_Date
# 0  DIA017339          Oval           Final     Failed      2023-03-08
# 1  DIA014663      Princess         Initial     Failed      2024-09-23
# 2  DIA016774       Emerald         Initial  Completed      2020-01-09
# 3  DIA015769          Oval    Intermediate     Failed      2020-01-11
# 4  DIA002426         Round         Initial     Failed      2023-03-07

# %%
# find correlation
df_num.corr()
# Out:
#                        Estimated_Yield_Carat  Actual_Yield_Carat  \
# Estimated_Yield_Carat               1.000000            0.006253
# Actual_Yield_Carat                  0.006253            1.000000
# Waste_Percentage                    0.000186            0.001081
#
#                        Waste_Percentage
# Estimated_Yield_Carat          0.000186
# Actual_Yield_Carat             0.001081
# Waste_Percentage               1.000000

# %%
# Plot the data using Scatter plot
sns.pairplot(df_num)

# %%
# Interpretation
# There is no significant relationship among the three numerical variables.
# The yield and waste percentage are not interdependent, indicating other factors play a role in determining the final output and efficiency.
# Further analysis with categorical variables (e.g., cutting style, status, assigned cutter) may help identify patterns affecting yield and waste.
#There is no significant correlation between Estimated Yield Carat, Actual Yield Carat, and Waste Percentage, indicating they are independent of each other.
# Other factors like cutting style or assigned cutter may influence the yield and waste percentage.

# %%
# We have done the Univariate Analysis of all the Numerical columns.

# %% [markdown]
# # M**ULTIVARIATE ANALYSIS**

# %%
#Multivariate analysis is not applicable here because the three numerical variables (`Estimated_Yield_Carat`, `Actual_Yield_Carat`, and `Waste_Percentage`) show near-zero correlation, indicating no strong interdependencies.
#Since multivariate analysis requires meaningful relationships among three or more variables, applying it in this case would not yield valuable insights.
